# %%
import pandas as pd

# %%
df = pd.read_csv('country_vaccination_stats.csv')
df
# Out:
#         country        date  daily_vaccinations  \
# 0     Argentina  12/29/2020                 NaN
# 1     Argentina  12/30/2020             15656.0
# 2     Argentina  12/31/2020             15656.0
# 3     Argentina    1/1/2021             11070.0
# 4     Argentina    1/2/2021              8776.0
# ...         ...         ...                 ...
# 1497      Wales   1/20/2021             11105.0
# 1498      Wales   1/21/2021             12318.0
# 1499      Wales   1/22/2021             15148.0
# 1500      Wales   1/23/2021             17371.0
# 1501      Wales   1/24/2021             17063.0
#
#                                  vaccines
# 0                               Sputnik V
# 1                               Sputnik V
# 2                               Sputnik V
# 3                               Sputnik V
# 4                               Sputnik V
# ...                                   ...
# 1497  Oxford/AstraZeneca, Pfizer/BioNTech
# ...

# %%
dfmedian = df.groupby("country").median() #ülkelere göre medyan alınır

# %%
dfmedian
# Out:
#                       daily_vaccinations
# country
# Argentina                        11704.0
# Austria                           7953.0
# Bahrain                           3871.0
# Belgium                           3634.0
# Brazil                           27304.0
# Bulgaria                          1013.0
# Canada                           11577.5
# Chile                             1328.5
# China                           299107.5
# Costa Rica                         763.0
# Croatia                           2497.5
# Cyprus                             729.5
# Czechia                           5812.0
# Denmark                           7139.0
# Ecuador                            108.0
# England                         115637.0
# Estonia                           1051.5
# Finland                           2332.0
# France                           43961.0
# Germany                          52415.5
# Gibraltar                          744.0
# Greece                            5388.0
# ...

# %%
dfsorted = dfmedian.sort_values(by = ['daily_vaccinations'], ascending = False).head(3)
dfsorted # veriler medyanlarına göre sıralanır ve ilk 3 ü seçilir
# Out:
#                daily_vaccinations
# country
# United States            399093.0
# China                    299107.5
# India                    182551.5
